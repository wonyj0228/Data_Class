# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../data10/world-happiness-report-2021.csv')
data
# Out:
#                  Country name            Regional indicator  Ladder score  \
# 0                     Finland                Western Europe         7.842
# 1                     Denmark                Western Europe         7.620
# 2                 Switzerland                Western Europe         7.571
# 3                     Iceland                Western Europe         7.554
# 4                 Netherlands                Western Europe         7.464
# 5                      Norway                Western Europe         7.392
# 6                      Sweden                Western Europe         7.363
# 7                  Luxembourg                Western Europe         7.324
# 8                 New Zealand         North America and ANZ         7.277
# 9                     Austria                Western Europe         7.268
# 10                  Australia         North America and ANZ         7.183
# 11                     Israel  Middle East and North Africa         7.157
# ...

# %%
ea = data[data['Regional indicator'] == 'East Asia'].copy()
ea
# Out:
#                  Country name Regional indicator  Ladder score  \
# 23   Taiwan Province of China          East Asia         6.584
# 55                      Japan          East Asia         5.940
# 61                South Korea          East Asia         5.845
# 69                   Mongolia          East Asia         5.677
# 76  Hong Kong S.A.R. of China          East Asia         5.477
# 83                      China          East Asia         5.339
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 23                           0.038         6.659         6.510
# 55                           0.040         6.020         5.861
# 61                           0.042         5.928         5.763
# 69                           0.042         5.760         5.595
# 76                           0.049         5.573         5.380
# 83                           0.029         5.397         5.281
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# ...

# %%
ea2 = ea.loc[:,['Country name','Ladder score','Healthy life expectancy']]

# %%
ea2.set_index('Country name', inplace = True)
ea2
# Out:
#                            Ladder score  Healthy life expectancy
# Country name
# Taiwan Province of China          6.584                   69.600
# Japan                             5.940                   75.100
# South Korea                       5.845                   73.900
# Mongolia                          5.677                   62.500
# Hong Kong S.A.R. of China         5.477                   76.820
# China                             5.339                   69.593

# %%
ea2.describe()
# Out:
#        Ladder score  Healthy life expectancy
# count      6.000000                 6.000000
# mean       5.810333                71.252167
# std        0.439913                 5.194238
# min        5.339000                62.500000
# 25%        5.527000                69.594750
# 50%        5.761000                71.750000
# 75%        5.916250                74.800000
# max        6.584000                76.820000

# %%
ea2.sort_values(by='Ladder score')
ea2
# Out:
#                            Ladder score  Healthy life expectancy
# Country name
# Taiwan Province of China          6.584                   69.600
# Japan                             5.940                   75.100
# South Korea                       5.845                   73.900
# Mongolia                          5.677                   62.500
# Hong Kong S.A.R. of China         5.477                   76.820
# China                             5.339                   69.593

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots(2,1, figsize = (10,10))
g1 = ea2['Ladder score'].plot.barh(ax = ax[0], title = 'Ladder score',fontsize=15)
g2= ea2['Healthy life expectancy'].plot.barh(ax = ax[1], title = 'Healthy life expectancy',fontsize=15)

# %% [markdown]
# **데이터자르기연습**

# %%
ea.iloc[:,0:3]
# Out:
#                  Country name Regional indicator  Ladder score
# 23   Taiwan Province of China          East Asia         6.584
# 55                      Japan          East Asia         5.940
# 61                South Korea          East Asia         5.845
# 69                   Mongolia          East Asia         5.677
# 76  Hong Kong S.A.R. of China          East Asia         5.477
# 83                      China          East Asia         5.339

# %%
ea.iloc[0]
# Out:
# Country name                                  Taiwan Province of China
# Regional indicator                                           East Asia
# Ladder score                                                     6.584
# Standard error of ladder score                                   0.038
# upperwhisker                                                     6.659
# lowerwhisker                                                      6.51
# Logged GDP per capita                                           10.871
# Social support                                                   0.898
# Healthy life expectancy                                           69.6
# Freedom to make life choices                                     0.784
# Generosity                                                       -0.07
# Perceptions of corruption                                        0.721
# Ladder score in Dystopia                                          2.43
# ...

# %%
ea.loc[:,'Country name']
# Out:
# 23     Taiwan Province of China
# 55                        Japan
# 61                  South Korea
# 69                     Mongolia
# 76    Hong Kong S.A.R. of China
# 83                        China
# Name: Country name, dtype: object

# %%
ea.loc[:,['Country name','Generosity']]
# Out:
#                  Country name  Generosity
# 23   Taiwan Province of China      -0.070
# 55                      Japan      -0.258
# 61                South Korea      -0.083
# 69                   Mongolia       0.116
# 76  Hong Kong S.A.R. of China       0.067
# 83                      China      -0.146

# %%
ea2
# Out:
#                            Ladder score  Healthy life expectancy
# Country name
# Taiwan Province of China          6.584                   69.600
# Japan                             5.940                   75.100
# South Korea                       5.845                   73.900
# Mongolia                          5.677                   62.500
# Hong Kong S.A.R. of China         5.477                   76.820
# China                             5.339                   69.593

# %%
ea2.shape
# Out:
# (6, 2)

# %%
ea2.iloc[0:6,0:2]
# Out:
#                            Ladder score  Healthy life expectancy
# Country name
# Taiwan Province of China          6.584                   69.600
# Japan                             5.940                   75.100
# South Korea                       5.845                   73.900
# Mongolia                          5.677                   62.500
# Hong Kong S.A.R. of China         5.477                   76.820
# China                             5.339                   69.593

# %%
ea2.loc[:,['Ladder score','Healthy life expectancy']]
# Out:
#                            Ladder score  Healthy life expectancy
# Country name
# Taiwan Province of China          6.584                   69.600
# Japan                             5.940                   75.100
# South Korea                       5.845                   73.900
# Mongolia                          5.677                   62.500
# Hong Kong S.A.R. of China         5.477                   76.820
# China                             5.339                   69.593

# %%
ea2.loc[['South Korea','Japan','China'],['Ladder score']]
# Out:
#               Ladder score
# Country name
# South Korea          5.845
# Japan                5.940
# China                5.339

# %%
ea2['Ladder score']
# Out:
# Country name
# Taiwan Province of China     6.584
# Japan                        5.940
# South Korea                  5.845
# Mongolia                     5.677
# Hong Kong S.A.R. of China    5.477
# China                        5.339
# Name: Ladder score, dtype: float64
